# %% [markdown]
# (2) Maping method

# %%
import pandas as pd

# %%
df = pd.read_excel("loan data.xlsx")
df.head()
# Out:
#   Loan_ID  Gender Married Dependents Education  ApplicantIncome  \
# 0  LP0001    Male     Yes        NaN  Graduate             2792
# 1  LP0002     NaN     NaN         3+       NaN             5885
# 2  LP0003    Male     Yes          1  Graduate             3832
# 3  LP0004  Female     NaN          2  Not Grad             6119
# 4  LP0005    Male     NaN          0  Not Grad             6434
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0        4597.524145       133.0             360.0             NaN
# 1           0.000000       184.0             120.0             1.0
# 2           0.000000         NaN             120.0             0.0
# 3           0.000000         NaN             240.0             NaN
# 4        1071.799900         NaN             360.0             NaN
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           Y
# 2         Rural           Y
# 3           NaN           Y
# 4           NaN           N

# %%
df["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', nan, 'Semiurban'], dtype=object)

# %%
df["Property_Area"].fillna(df["Property_Area"].mode()[0],inplace =True)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
order_data = [['Urban', 'Semiurban', 'Rural']]

# %%
oe = OrdinalEncoder(categories=order_data)

# %%
oe.fit_transform(df[["Property_Area"]])
# Out:
# array([[0.],
#        [2.],
#        [2.],
#        ...,
#        [1.],
#        [1.],
#        [2.]], shape=(2000, 1))

# %%
df["Property_Area"]= oe.fit_transform(df[["Property_Area"]])

# %%
df.head(10)
# Out:
#   Loan_ID  Gender Married Dependents Education  ApplicantIncome  \
# 0  LP0001    Male     Yes        NaN  Graduate             2792
# 1  LP0002     NaN     NaN         3+       NaN             5885
# 2  LP0003    Male     Yes          1  Graduate             3832
# 3  LP0004  Female     NaN          2  Not Grad             6119
# 4  LP0005    Male     NaN          0  Not Grad             6434
# 5  LP0006     NaN     NaN         3+  Not Grad             5227
# 6  LP0007    Male      No         3+  Not Grad             9041
# 7  LP0008    Male      No          2  Graduate             7292
# 8  LP0009     NaN     Yes         3+  Not Grad             7458
# 9  LP0010     NaN     Yes          1  Graduate             2756
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0        4597.524145       133.0             360.0             NaN
# 1           0.000000       184.0             120.0             1.0
# 2           0.000000         NaN             120.0             0.0
# 3           0.000000         NaN             240.0             NaN
# 4        1071.799900         NaN             360.0             NaN
# 5         849.756786       153.0             240.0             0.0
# 6           0.000000       133.0             240.0             NaN
# 7        1987.063381         NaN             180.0             0.0
# 8           0.000000        73.0             120.0             1.0
# 9         519.006552        82.0             240.0             NaN
#
#    Property_Area Loan_Status
# 0            0.0           Y
# 1            2.0           Y
# 2            2.0           Y
# 3            0.0           Y
# 4            0.0           N
# 5            0.0           Y
# 6            1.0           N
# 7            1.0           Y
# 8            0.0           Y
# 9            1.0           N
