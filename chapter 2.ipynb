# %% [markdown]
# HANDELING CATEGORICAL DATA MISSING VALUE

# %%
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ayush/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/ayush/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('loan data.xlsx')
df.head()
# Out:
#   Loan_ID  Gender Married Dependents Education  ApplicantIncome  \
# 0  LP0001    Male     Yes        NaN  Graduate             2792
# 1  LP0002     NaN     NaN         3+       NaN             5885
# 2  LP0003    Male     Yes          1  Graduate             3832
# 3  LP0004  Female     NaN          2  Not Grad             6119
# 4  LP0005    Male     NaN          0  Not Grad             6434
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0        4597.524145       133.0             360.0             NaN
# 1           0.000000       184.0             120.0             1.0
# 2           0.000000         NaN             120.0             0.0
# 3           0.000000         NaN             240.0             NaN
# 4        1071.799900         NaN             360.0             NaN
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           Y
# 2         Rural           Y
# 3           NaN           Y
# 4           NaN           N

# %%
#df.fillna(method="bfill")
# Out:
# /var/folders/1b/sb7118x92zdbwm1h5l66vt9w0000gn/T/ipykernel_3713/3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#      Loan_ID  Gender Married Dependents Education  ApplicantIncome  \
# 0     LP0001    Male     Yes         3+  Graduate             2792
# 1     LP0002    Male     Yes         3+  Graduate             5885
# 2     LP0003    Male     Yes          1  Graduate             3832
# 3     LP0004  Female      No          2  Not Grad             6119
# 4     LP0005    Male      No          0  Not Grad             6434
# ...      ...     ...     ...        ...       ...              ...
# 1995  LP1996    Male      No          1  Graduate             4298
# 1996  LP1997    Male     Yes          0  Graduate             3031
# 1997  LP1998    Male      No          2  Not Grad             5612
# 1998  LP1999  Female      No          0  Not Grad             4741
# 1999  LP2000  Female      No          0       NaN             3223
#
#       CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0           4597.524145       133.0             360.0             1.0
# 1              0.000000       184.0             120.0             1.0
# 2              0.000000       153.0             120.0             0.0
# 3              0.000000       153.0             240.0             0.0
# 4           1071.799900       153.0             360.0             0.0
# ...                 ...         ...               ...             ...
# 1995           0.000000       143.0             180.0             1.0
# 1996        1486.758032       143.0             120.0             1.0
# 1997           0.000000       197.0             240.0             1.0
# 1998        4959.248789       197.0             360.0             NaN
# 1999           0.000000         NaN             360.0             NaN
#
#      Property_Area Loan_Status
# 0            Urban           Y
# 1            Rural           Y
# 2            Rural           Y
# 3        Semiurban           Y
# 4        Semiurban           N
# ...            ...         ...
# 1995         Urban           Y
# 1996     Semiurban           N
# 1997     Semiurban           N
# 1998     Semiurban           N
# 1999         Rural           Y
#
# [2000 rows x 12 columns]

# %%
#df.fillna(method="ffill",axis=1)
# Out:
# /var/folders/1b/sb7118x92zdbwm1h5l66vt9w0000gn/T/ipykernel_3713/3252714673.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill",axis=1)
#      Loan_ID  Gender Married Dependents Education ApplicantIncome  \
# 0     LP0001    Male     Yes        Yes  Graduate            2792
# 1     LP0002  LP0002  LP0002         3+        3+            5885
# 2     LP0003    Male     Yes          1  Graduate            3832
# 3     LP0004  Female  Female          2  Not Grad            6119
# 4     LP0005    Male    Male          0  Not Grad            6434
# ...      ...     ...     ...        ...       ...             ...
# 1995  LP1996    Male      No          1         1            4298
# 1996  LP1997  LP1997     Yes          0  Graduate            3031
# 1997  LP1998    Male      No          2  Not Grad            5612
# 1998  LP1999  LP1999  LP1999     LP1999  Not Grad            4741
# 1999  LP2000  Female      No          0         0            3223
#
#      CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# 0          4597.524145      133.0            360.0          360.0
# 1                  0.0      184.0            120.0            1.0
# 2                  0.0        0.0            120.0            0.0
# 3                  0.0        0.0            240.0          240.0
# 4            1071.7999  1071.7999            360.0          360.0
# ...                ...        ...              ...            ...
# 1995               0.0        0.0            180.0            1.0
# 1996       1486.758032      143.0            120.0            1.0
# 1997               0.0        0.0            240.0            1.0
# 1998       4959.248789      197.0            197.0          197.0
# 1999               0.0        0.0            360.0          360.0
#
#      Property_Area Loan_Status
# 0            Urban           Y
# 1            Rural           Y
# 2            Rural           Y
# 3            240.0           Y
# 4            360.0           N
# ...            ...         ...
# 1995         Urban           Y
# 1996     Semiurban           N
# 1997     Semiurban           N
# 1998     Semiurban           N
# 1999         Rural           Y
#
# [2000 rows x 12 columns]

# %%
df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df['Gender'].fillna(df['Gender'].mode()[0]).inplace=True

# %%
df.head()
# Out:
#   Loan_ID  Gender Married Dependents Education  ApplicantIncome  \
# 0  LP0001    Male     Yes        NaN  Graduate             2792
# 1  LP0002     NaN     NaN         3+       NaN             5885
# 2  LP0003    Male     Yes          1  Graduate             3832
# 3  LP0004  Female     NaN          2  Not Grad             6119
# 4  LP0005    Male     NaN          0  Not Grad             6434
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0        4597.524145       133.0             360.0             NaN
# 1           0.000000       184.0             120.0             1.0
# 2           0.000000         NaN             120.0             0.0
# 3           0.000000         NaN             240.0             NaN
# 4        1071.799900         NaN             360.0             NaN
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           Y
# 2         Rural           Y
# 3           NaN           Y
# 4           NaN           N

# %%
for i in df.select_dtypes(include= "object").columns:
    df[i].fillna(df[i].mod()[0],inplace=true) # type: ignore
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 for i in df.select_dtypes(include= "object").columns:
# ----> 2     df[i].fillna(df[i].mod()[0],inplace=true) # type: ignore
#
# TypeError: Series.mod() missing 1 required positional argument: 'other'
